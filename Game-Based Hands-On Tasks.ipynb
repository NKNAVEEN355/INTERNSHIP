# %%
import random
wanttoplay=(input("hit enter to play"))

gamewanaplay=int(input("'which game do you wanna play \n 1) Guess the Number\n 2) ROCK PAPER AND SCISSORS\n 3) Quiz Game'"))
if gamewanaplay == 1:
    numofguess= int(input("enter number of guesses:"))
    a=int(input("min number to guess between:"))
    b=int(input("max number to guess between:"))
    attempts=1
    
    while numofguess>=attempts:
        randomgentoguess=random.randint(a,b)
        yourguess=int(input("whats your guess between"+str(a)+" and "+str(b)+":"))
        attempts+=1
        if yourguess==randomgentoguess:
            print("you won this round")
        elif yourguess>randomgentoguess:
            print("your guess "+str(yourguess)+" is too high")   
        else:
            print("your guess "+str(yourguess)+" is too low")
elif gamewanaplay == 2:
    gamechoises=["rock","paper","scissor"]
    win=0
    loss=0
    want_to_playy=True
    while want_to_playy==True:
        randomchoice=random.choices(gamechoises)
        yourchoicee=str(input("what is your choise rock, paper, scissor enter the option :"))
        for yourchoicee in gamechoises:
            if yourchoicee==randomchoice:
                print("try again")
                break
                
            else:
                if yourchoicee == "rock":
                    if randomchoice=="scissor":
                        win+=1
                        print("you win, total no of wins is "+str(win)+"total no of loss is "+str(loss))
                        want_to_playy=bool(input("enter any thing and press enter to play again\n if not just press enter"))
                        break
                        
                    else:
                        loss+=1
                        print("you lost, total no of wins is "+str(win)+"total no of loss is "+str(loss))
                        want_to_playy=bool(input("enter any thing and press enter to play again\n if not just press enter"))
                        break
                elif yourchoicee == "paper":
                    if randomchoice=="scissor":
                        loss+=1
                        print("you lost, total no of wins is "+str(win)+"total no of loss is "+str(loss))                        
                        want_to_playy=bool(input("enter any thing and press enter to play again\n if not just press enter"))
                        break
                    else :
                        win+=1
                        print("you win, total no of wins is "+str(win)+"total no of loss is "+str(loss))
                        want_to_playy=bool(input("enter any thing and press enter to play again\n if not just press enter"))
                        break
                        
                elif yourchoicee == "scissor":
                    if randomchoice=="rock":
                        loss+=1
                        print("you lost, total no of wins is "+str(win)+"total no of loss is "+str(loss))                        
                        want_to_playy=bool(input("enter any thing and press enter to play again\n if not just press enter"))
                        break
                    else :
                        win+=1
                        print("you win, total no of wins is "+str(win)+"total no of loss is "+str(loss))
                        want_to_playy=bool(input("enter any thing and press enter to play again\n if not just press enter"))
                        break
elif  gamewanaplay == 3:
    qanda={
    "What is the capital of France?": "Paris",
    "Who painted the Mona Lisa?": "Leonardo da Vinci",
    "What is the largest ocean on Earth?": "Pacific Ocean",
    "How many planets are in our solar system?": "Eight",
    "What is the chemical symbol for water?": "H2O",
    "Who wrote 'Romeo and Juliet'?": "William Shakespeare",
    "What is the highest mountain in the world?": "Mount Everest",
    "What is the currency of Japan?": "Japanese Yen",
    "What is the fastest land animal?": "Cheetah",
    "Which country is known as the Land of the Rising Sun?": "Japan",
    "What is the main ingredient in guacamole?": "Avocado",
    "Who invented the light bulb?": "Thomas Edison",
    "What is the smallest continent?": "Australia",
    "What is the longest river in the world?": "Nile River",
    "What is the anther name for 'The Lion City'?": "Singapore",
    "Which planet is known as the 'Red Planet'?": "Mars",
    "What is the largest desert in the world?": "Sahara Desert",
    "What is the primary gas that makes up the Earth's atmosphere?": "Nitrogen",
    "Who was the first man on the moon?": "Neil Armstrong",
    "What is the national animal of India?": "Tiger",
    "What is the capital of Australia?": "Canberra",
    "What is the official language of Brazil?": "Portuguese",
    "What is the largest anaconda found in the world?": "Green Anaconda",
    "What is the biggest mammal on Earth?": "Blue Whale",
    "What is the deepest point in the Earth's oceans?": "Mariana Trench",
    "Who developed the theory of relativity?": "Albert Einstein",
    "What is the most populous country in the world?": "India",
    "What is the hardest natural substance on Earth?": "Diamond",
    "What is the main component of the sun?": "Hydrogen",
    "What is the capital of Canada?": "Ottawa",
    "What is the longest great wall in the world?": "Great Wall of China",
    "What is the color of the sky?": "Blue",
    "What is the symbol for gold?": "Au",
    "What is the largest artificial lake in the world?": "Lake Kariba",
    "Who wrote 'To Kill a Mockingbird'?": "Harper Lee",
    "What is the smallest country in the world?": "Vatican City",
    "What is the largest organ in the human body?": "Skin",
    "What is the process by which plants make their own food?": "Photosynthesis",
    "What is the capital of Germany?": "Berlin",
    "Who is known as the 'Father of Modern Physics'?": "Albert Einstein",
    "What is the highest waterfall in the world?": "Angel Falls",
    "What is the capital of Italy?": "Rome",
    "What is the most common element in the universe?": "Hydrogen",
    "What is the name of the galaxy our solar system is in?": "Milky Way",
    "What is the national flower of Japan?": "Cherry Blossom",
    "What is the currency of the United Kingdom?": "Pound Sterling",
    "What is the famous fictional detective who lived at 221B Baker Street?": "Sherlock Holmes",
    "What is the approximate age of the Earth?": "4.54 billion years",
    "What is the largest land animal?": "African Bush Elephant",
    "Who discovered penicillin?": "Alexander Fleming"}
    no_of_currect=0
    no_of_wrong=0
    listqanda = list(qanda.items())
    for i in range(len(listqanda)):
        a=random.randint(0,len(listqanda)-1)
        res = listqanda[a]
        print("question is "+str(res[0])+"\n  ")
        i+=1
        uranswer=(str(input("ur answer to the question is:")))
        sysans=str(res[1])
        if sysans== uranswer:
            no_of_currect+=1
            print("its a right answer :\n no of thecurrect answers are: "+str(no_of_currect)+"\n no of the wrong answers are:\n"+str(no_of_wrong))
        else:
            no_of_wrong+=1
            print("its a wrong answer :\n no of thecurrect answers are: "+str(no_of_currect)+"\n no of the wrong answers are:\n"+str(no_of_wrong))

            
    
else:
    print("error invalid option")
